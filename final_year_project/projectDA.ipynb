# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Data.csv')
print(df.shape)
df.head()
# Out:
# (506, 14)
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
features = df.drop('MEDV', axis = 1)
features.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
features.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734  \
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 10))
correlation = features.corr()
cmap = sns.diverging_palette(500, 10, as_cmap=True)
sns.heatmap(correlation.abs(), cmap=cmap, center=0, square=True, annot=True)
plt.title('Correlation Matrix');

# %%
target = df['MEDV']

# %%
sns.boxplot(correlation.abs())
# Out:
# <Axes: >

# %%
X = features
y = df['MEDV']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, test_size=0.3)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# baseline for both mse and mae
y_mean = y_train.mean()
y_pred_baseline = [y_mean] * len(y_train)

y_mse_baseline = mean_squared_error(y_train, y_pred_baseline)
y_mae_baseline = mean_absolute_error(y_train, y_pred_baseline)

print(f'baseline for MSE {y_mse_baseline} and baseline for MAE {y_mae_baseline}')
# Out:
# baseline for MSE 81.18906324810878 and baseline for MAE 6.5473666570908735

# %%
z = []
for i, j in zip(y_train, y_pred_baseline):
    z.append(i-j)

# %%
len(z)
# Out:
# 354

# %%
b = []
for d in z:
    b.append(d**2)

# %%
sum(b)/len(b)
# Out:
# 81.1890632481089

# %%
p = []
for i, j in zip(y_train, y_pred_baseline):
    p.append(abs(i-j))

# %%
sum(p)
# Out:
# 2317.767796610168

# %%
sum(p)/len(p)
# Out:
# 6.547366657090869

# %%
from sklearn.linear_model import LinearRegression, Ridge

# %%
model1= LinearRegression()
model2= Ridge()

# %%
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model2.fit(X_train, y_train)
# Out:
# Ridge()

# %%
prediction = model1.predict(X_test)
model1_mse = mean_squared_error(y_test, prediction)
model1_mae = mean_absolute_error(y_test, prediction)
print(f'Model 1 MSE {model1_mse} and MAE {model1_mae}')
# Out:
# Model 1 MSE 19.831323672063046 and MAE 3.344665503598754

# %%
prediction = model2.predict(X_test)
model2_mse = mean_squared_error(y_test, prediction)
model2_mae = mean_absolute_error(y_test, prediction)
print(f'Model 1 MSE {model2_mse} and MAE {model2_mae}')
# Out:
# Model 1 MSE 19.33441628784364 and MAE 3.2890418959157652

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor

# %%
model3 = RandomForestRegressor(random_state=1, n_estimators=100, n_jobs=10)
model4 = AdaBoostRegressor(random_state=42, n_estimators=50)

# %%
model3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=10, random_state=1)

# %%
model4.fit(X_train, y_train)
# Out:
# AdaBoostRegressor(random_state=42)

# %%
prediction3 = model3.predict(X_test)
model3_mse = mean_squared_error(y_test, prediction3)
model3_mae = mean_absolute_error(y_test, prediction3)
print(f'Model 1 MSE {model3_mse} and MAE {model3_mae}')
# Out:
# Model 1 MSE 8.490417302631572 and MAE 2.225197368421052

# %%
prediction4 = model4.predict(X_test)
model4_mse = mean_squared_error(y_test, prediction4)
model4_mae = mean_absolute_error(y_test, prediction4)
print(f'Model 1 MSE {model4_mse} and MAE {model4_mae}')
# Out:
# Model 1 MSE 15.861712912536982 and MAE 3.129442502087363

# %%
from sklearn.ensemble import ExtraTreesRegressor

# %%
model5 = ExtraTreesRegressor(random_state=1, n_estimators=100)

model5.fit(X_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=1)

# %%
prediction5 = model5.predict(X_test)
model5_mse = mean_squared_error(y_test, prediction5)
model5_mae = mean_absolute_error(y_test, prediction5)
print(f'Model 1 MSE {model5_mse} and MAE {model5_mae}')
# Out:
# Model 1 MSE 7.485059703947376 and MAE 2.0534802631578954

# %%
prediction5
# Out:
# array([28.873, 27.097, 20.024, 20.935, 24.017, 19.927, 28.325, 18.389,
#        21.264, 23.028, 26.771, 31.706, 20.478, 20.61 , 20.505, 22.932,
#        12.5  , 39.553, 23.407, 14.397, 19.639, 16.692, 24.74 , 23.759,
#        25.237,  8.894, 14.178, 20.037, 38.383, 12.157, 26.67 , 19.587,
#        48.418, 16.292, 21.879, 20.83 , 16.242, 32.225, 14.261, 19.872,
#        24.158, 22.752, 26.508, 14.712, 15.358, 11.958, 49.454, 12.631,
#        23.213, 19.7  , 22.732, 21.855, 25.423, 21.976,  9.106, 23.932,
#        12.061, 23.119, 17.725, 41.11 , 14.256, 25.987, 12.561, 15.635,
#        17.421, 32.543, 39.186, 25.24 , 21.626, 20.202, 23.644,  7.474,
#        18.959, 21.066, 19.404, 20.777, 45.111, 25.19 , 27.483, 34.261,
#        17.35 , 19.577, 34.05 , 12.232, 24.498, 25.289, 14.986, 24.397,
#        19.27 , 16.666, 24.808, 46.636, 15.345, 21.639, 15.168, 20.165,
#        22.96 , 25.112, 39.959, 20.461, 16.543, 15.227, 24.241, 22.928,
# ...

# %%
z = []
for i, j in zip(y_test, prediction5):
    z.append(i-j)

# %%
len(b)
# Out:
# 152

# %%
b = []
for d in z:
    b.append(d**2)

# %%
sum(b)/len(b)
# Out:
# 7.485059703947374

# %%
p = []
for i, j in zip(y_test, prediction5):
    p.append(abs(i-j))

# %%
sum(p)/len(p)
# Out:
# 2.0534802631578954

# %%
prediction3
# Out:
# array([29.652, 27.951, 20.236, 21.109, 20.089, 19.515, 28.409, 19.187,
#        19.865, 23.863, 26.777, 32.044, 20.492, 20.14 , 20.151, 27.561,
#        11.988, 39.756, 24.422, 14.484, 19.906, 16.367, 24.347, 23.892,
#        26.716,  9.341, 14.044, 19.709, 40.209, 12.402, 26.806, 20.477,
#        47.775, 16.21 , 22.692, 20.68 , 15.314, 32.504, 12.621, 20.095,
#        24.542, 23.291, 25.676, 15.354, 15.829, 11.775, 48.336, 12.103,
#        21.225, 18.867, 24.218, 21.541, 24.908, 20.887, 10.4  , 24.255,
#        11.844, 23.716, 18.571, 41.558, 14.697, 27.386, 13.246, 15.315,
#        17.747, 33.222, 41.444, 25.662, 21.579, 20.455, 24.004,  7.041,
#        18.976, 21.704, 19.501, 20.61 , 44.406, 24.556, 27.188, 32.875,
#        16.927, 20.767, 32.957, 11.467, 24.864, 26.182, 15.024, 24.739,
#        19.78 , 17.067, 28.131, 43.019, 16.25 , 21.009, 15.34 , 20.227,
#        23.006, 23.558, 41.921, 20.601, 16.755, 15.33 , 24.236, 23.684,
# ...

# %%
y_test
# Out:
# 307    28.2
# 343    23.9
# 47     16.6
# 67     22.0
# 362    20.8
#        ...
# 467    19.1
# 95     28.4
# 122    20.5
# 260    33.8
# 23     14.5
# Name: MEDV, Length: 152, dtype: float64

# %%
import shap
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
explainer = shap.TreeExplainer(model3)

# %%
feature_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# %%
ddd = X_test.loc[[343]]

# %%
ddd
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 343  0.02543  55.0   3.78     0  0.484  6.696  56.4  5.7321    5  370  \
#
#      PTRATIO      B  LSTAT
# 343     17.6  396.9   7.18

# %%
shap_values = explainer.shap_values(ddd)
shap.initjs()
shap.force_plot(explainer.expected_value, shap_values, ddd)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,
# ...

# %%
shap.summary_plot(shap_values, X_train)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 shap.summary_plot(shap_values, X_train)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\shap\plots\_beeswarm.py:695, in summary_legacy(shap_values, features, feature_names, max_display, plot_type, color, axis_color, title, alpha, show, sort, color_bar, plot_size, layered_violin_max_num_bins, class_names, class_inds, color_bar_label, cmap, auto_size_plot, use_log_scale)
#     692 if vmin > vmax: # fixes rare numerical precision issues
#     693     vmin = vmax
# --> 695 assert features.shape[0] == len(shaps), "Feature and SHAP matrices must have the same number of rows!"
#     697 # plot the nan values in the interaction feature as grey
#     698 nan_mask = np.isnan(values)
#
# AssertionError: Feature and SHAP matrices must have the same number of rows!

# %%
explainer = shap.TreeExplainer(model3)
shap_values = explainer.shap_values(X)

# %%
X
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
shap.summary_plot(shap_values, X)
# Out:
# No data for colormapping provided via 'c'. Parameters 'vmin', 'vmax' will be ignored

# %%
shap.summary_plot(shap_values, X, plot_type="bar")

# %%
importance = model3.feature_importances_

# %%
feature_names = X.columns
sorted_feature_names = feature_names[sorted_indices]

# %%
import matplotlib.pyplot as plt

# Sort feature importance in descending order
sorted_indices = np.argsort(importance)[::-1]
sorted_importance = importance[sorted_indices]

# Create a bar plot
plt.bar(range(X_train.shape[1]), sorted_importance, align='center')
plt.xticks(range(X_train.shape[1]), sorted_feature_names, rotation=90)
plt.xlabel('Features')
plt.ylabel('Importance')
plt.title('Feature Importance in Boston Housing Dataset')

# Show the plot
plt.show()

# %%
# pickle start
import pickle

df = pd.read_csv('Data.csv')
features = df.drop('MEDV', axis = 1)
X = features
y = df['MEDV']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, test_size=0.3)

model3 = RandomForestRegressor(n_estimators=100, n_jobs=10, random_state=1)
model3.fit(X_train, y_train)

model3_mse = mean_squared_error(y_test, prediction3)
model3_mae = mean_absolute_error(y_test, prediction3)
print(f'Model 1 MSE {model3_mse} and MAE {model3_mae}')

with open('model3.pkle', 'wb') as f:
    pickle.dump(model3, f)
# Out:
# Model 1 MSE 8.49041730263157 and MAE 2.225197368421052

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your predicted and actual values stored in separate arrays or variables
predicted_values = model3.predict(X_test)
actual_values = y_test

# Create a scatter plot
plt.scatter(actual_values, predicted_values, color='b', label='Predicted vs. Actual')

# Add a diagonal line representing perfect predictions
plt.plot([min(actual_values), max(actual_values)], [min(actual_values), max(actual_values)], color='r', label='Perfect Prediction')

# Add labels and a legend
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your predicted and actual values stored in separate arrays or variables
predicted_values = model3.predict(X_test)
actual_values = y_test

# Create a scatter plot with different marker styles or colors
plt.scatter(actual_values, predicted_values, color='b', label='Predicted', marker='s')
plt.scatter(actual_values, actual_values, color='r', label='Actual', marker='o')

# Add labels and a legend
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.legend()

# Show the plot
plt.show()
