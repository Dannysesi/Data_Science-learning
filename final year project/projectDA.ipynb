# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Data.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000  \
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
features = df.drop('MEDV', axis = 1)
features.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
features.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734  \
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(20, 10))
correlation = features.corr()
cmap = sns.diverging_palette(500, 10, as_cmap=True)
sns.heatmap(correlation.abs(), cmap=cmap, center=0, square=True, annot=True)
plt.title('Correlation Matrix');

# %%
target = df['MEDV']

# %%
sns.boxplot(correlation.abs())
# Out:
# <Axes: >

# %%
X = features
y = df['MEDV']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, test_size=0.3)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
# baseline for both mse and mae
y_mean = y_train.mean()
y_pred_baseline = [y_mean] * len(y_train)

y_mse_baseline = mean_squared_error(y_train, y_pred_baseline)
y_mae_baseline = mean_absolute_error(y_train, y_pred_baseline)

print(f'baseline for MSE {y_mse_baseline} and baseline for MAE {y_mae_baseline}')
# Out:
# baseline for MSE 81.18906324810878 and baseline for MAE 6.5473666570908735

# %%
from sklearn.linear_model import LinearRegression, Ridge

# %%
model1= LinearRegression()
model2= Ridge()

# %%
model1.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model2.fit(X_train, y_train)
# Out:
# Ridge()

# %%
prediction = model1.predict(X_test)
model1_mse = mean_squared_error(y_test, prediction)
model1_mae = mean_absolute_error(y_test, prediction)
print(f'Model 1 MSE {model1_mse} and MAE {model1_mae}')
# Out:
# Model 1 MSE 19.831323672063046 and MAE 3.344665503598754

# %%
prediction = model2.predict(X_test)
model2_mse = mean_squared_error(y_test, prediction)
model2_mae = mean_absolute_error(y_test, prediction)
print(f'Model 1 MSE {model2_mse} and MAE {model2_mae}')
# Out:
# Model 1 MSE 19.33441628784364 and MAE 3.2890418959157652

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model3 = RandomForestRegressor(random_state=1, n_estimators=100, n_jobs=10)

# %%
model3.fit(X_train, y_train)
# Out:
# RandomForestRegressor(n_jobs=10, random_state=1)

# %%
prediction3 = model3.predict(X_test)
model3_mse = mean_squared_error(y_test, prediction3)
model3_mae = mean_absolute_error(y_test, prediction3)
print(f'Model 1 MSE {model3_mse} and MAE {model3_mae}')
# Out:
# Model 1 MSE 8.49041730263157 and MAE 2.225197368421052

# %%
# pickle start
import pickle

df = pd.read_csv('Data.csv')
features = df.drop('MEDV', axis = 1)
X = features
y = df['MEDV']

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=1, test_size=0.3)

model3 = RandomForestRegressor(n_estimators=100, n_jobs=10, random_state=1)
model3.fit(X_train, y_train)

model3_mse = mean_squared_error(y_test, prediction3)
model3_mae = mean_absolute_error(y_test, prediction3)
print(f'Model 1 MSE {model3_mse} and MAE {model3_mae}')

with open('model3.pkl', 'wb') as f:
    pickle.dump(model3, f)
# Out:
# Model 1 MSE 8.49041730263157 and MAE 2.225197368421052
