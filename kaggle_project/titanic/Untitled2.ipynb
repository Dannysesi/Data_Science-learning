# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data = data.drop(['Name', 'Ticket', 'Fare', 'PassengerId', 'Cabin'], axis=1)
data.head(20)
# Out:
#     Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0          0       3    male  22.0      1      0        S
# 1          1       1  female  38.0      1      0        C
# 2          1       3  female  26.0      0      0        S
# 3          1       1  female  35.0      1      0        S
# 4          0       3    male  35.0      0      0        S
# 5          0       3    male   NaN      0      0        Q
# 6          0       1    male  54.0      0      0        S
# 7          0       3    male   2.0      3      1        S
# 8          1       3  female  27.0      0      2        S
# 9          1       2  female  14.0      1      0        C
# 10         1       3  female   4.0      1      1        S
# 11         1       1  female  58.0      0      0        S
# 12         0       3    male  20.0      0      0        S
# 13         0       3    male  39.0      1      5        S
# 14         0       3  female  14.0      0      0        S
# ...

# %%
mean = data.Age.mean()
data.Age.fillna(mean,inplace=True)

# %%
data.head(20)
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch Embarked
# 0          0       3    male  22.000000      1      0        S
# 1          1       1  female  38.000000      1      0        C
# 2          1       3  female  26.000000      0      0        S
# 3          1       1  female  35.000000      1      0        S
# 4          0       3    male  35.000000      0      0        S
# 5          0       3    male  29.699118      0      0        Q
# 6          0       1    male  54.000000      0      0        S
# 7          0       3    male   2.000000      3      1        S
# 8          1       3  female  27.000000      0      2        S
# 9          1       2  female  14.000000      1      0        C
# 10         1       3  female   4.000000      1      1        S
# 11         1       1  female  58.000000      0      0        S
# 12         0       3    male  20.000000      0      0        S
# 13         0       3    male  39.000000      1      5        S
# ...

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Embarked    2
# dtype: int64

# %%
data.Embarked.fillna('U', inplace=True)
data.head(20)
# Out:
#     Survived  Pclass     Sex        Age  SibSp  Parch Embarked
# 0          0       3    male  22.000000      1      0        S
# 1          1       1  female  38.000000      1      0        C
# 2          1       3  female  26.000000      0      0        S
# 3          1       1  female  35.000000      1      0        S
# 4          0       3    male  35.000000      0      0        S
# 5          0       3    male  29.699118      0      0        Q
# 6          0       1    male  54.000000      0      0        S
# 7          0       3    male   2.000000      3      1        S
# 8          1       3  female  27.000000      0      2        S
# 9          1       2  female  14.000000      1      0        C
# 10         1       3  female   4.000000      1      1        S
# 11         1       1  female  58.000000      0      0        S
# 12         0       3    male  20.000000      0      0        S
# 13         0       3    male  39.000000      1      5        S
# ...

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test = test.drop(['Name', 'Ticket', 'Fare', 'PassengerId', 'Cabin'], axis=1)
test.head(10)
# Out:
#    Pclass     Sex   Age  SibSp  Parch Embarked
# 0       3    male  34.5      0      0        Q
# 1       3  female  47.0      1      0        S
# 2       2    male  62.0      0      0        Q
# 3       3    male  27.0      0      0        S
# 4       3  female  22.0      1      1        S
# 5       3    male  14.0      0      0        S
# 6       3  female  30.0      0      0        Q
# 7       2    male  26.0      1      1        S
# 8       3  female  18.0      0      0        C
# 9       3    male  21.0      2      0        S

# %%
test.isnull().sum()
# Out:
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Embarked     0
# dtype: int64

# %%
mean2 = test.Age.mean()
test.Age.fillna(mean, inplace=True)
test.head(10)
# Out:
#    Pclass     Sex   Age  SibSp  Parch Embarked
# 0       3    male  34.5      0      0        Q
# 1       3  female  47.0      1      0        S
# 2       2    male  62.0      0      0        Q
# 3       3    male  27.0      0      0        S
# 4       3  female  22.0      1      1        S
# 5       3    male  14.0      0      0        S
# 6       3  female  30.0      0      0        Q
# 7       2    male  26.0      1      1        S
# 8       3  female  18.0      0      0        C
# 9       3    male  21.0      2      0        S

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

while True:
    data['Sex'] = le.fit_transform(data['Sex'])
    data['Embarked'] = le.fit_transform(data['Embarked'])
    test['Sex'] = le.fit_transform(test['Sex'])
    test['Embarked'] = le.fit_transform(test['Embarked'])
    print(le.classes_)
    break
# Out:
# ['C' 'Q' 'S']

# %%
data.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch  Embarked
# 0         0       3    1  22.0      1      0         2
# 1         1       1    0  38.0      1      0         0
# 2         1       3    0  26.0      0      0         2
# 3         1       1    0  35.0      1      0         2
# 4         0       3    1  35.0      0      0         2

# %%
data.Embarked.unique()
# Out:
# array([2, 0, 1, 3])

# %%
test.head(10)
# Out:
#    Pclass  Sex   Age  SibSp  Parch  Embarked
# 0       3    1  34.5      0      0         1
# 1       3    0  47.0      1      0         2
# 2       2    1  62.0      0      0         1
# 3       3    1  27.0      0      0         2
# 4       3    0  22.0      1      1         2
# 5       3    1  14.0      0      0         2
# 6       3    0  30.0      0      0         1
# 7       2    1  26.0      1      1         2
# 8       3    0  18.0      0      0         0
# 9       3    1  21.0      2      0         2

# %%
test.Embarked.unique()
# Out:
# array([1, 2, 0])

# %%
y = data.Survived
features= ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Embarked']
X = data[features]

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

lrmodel = LogisticRegression(random_state=1)

X_train, X_val, y_train, y_val = train_test_split(X,y, random_state=1)
lrmodel.fit(X_train, y_train)
lrprediction = lrmodel.predict(X_val)

lras = accuracy_score(y_val, lrprediction)

print(f'the validation accuracy score for logistic regression is {lras}')
# Out:
# the validation accuracy score for logistic regression is 0.8026905829596412

# %%
test_data = pd.read_csv('test.csv')

# %%
test_X = test[features]
lrmodelonfulldata = LogisticRegression(random_state=1)


lrmodelonfulldata.fit(X, y)
# Out:
# LogisticRegression(random_state=1)

# %%
test_preds = lrmodelonfulldata.predict(test_X)

# %%
# output = pd.DataFrame({'PassengerId': test_data.PassengerId,
#                        'Survived': test_preds})
# output.to_csv('submission2.csv', index=False)
