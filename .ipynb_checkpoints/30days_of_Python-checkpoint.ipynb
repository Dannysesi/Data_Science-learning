# %% [markdown]
# # Day 1

# %%
x = 0
while x <= 9:
    for i in range(0, 13):
        print(f'{x} * {i} = ', x*i)
    print(end='\n')
    x+=1
# Out:
# Enter value: 3
# 3 * 0 =  0
# 3 * 1 =  3
# 3 * 2 =  6
# 3 * 3 =  9
# 3 * 4 =  12
# 3 * 5 =  15
# 3 * 6 =  18
# 3 * 7 =  21
# 3 * 8 =  24
# 3 * 9 =  27
# 3 * 10 =  30
# 3 * 11 =  33
# 3 * 12 =  36
#
# 4 * 0 =  0
# 4 * 1 =  4
# 4 * 2 =  8
# 4 * 3 =  12
# 4 * 4 =  16
# 4 * 5 =  20
# 4 * 6 =  24
# 4 * 7 =  28
# 4 * 8 =  32
# 4 * 9 =  36
# 4 * 10 =  40
# 4 * 11 =  44
# 4 * 12 =  48
#
# 5 * 0 =  0
# 5 * 1 =  5
# 5 * 2 =  10
# 5 * 3 =  15
# 5 * 4 =  20
# 5 * 5 =  25
# 5 * 6 =  30
# 5 * 7 =  35
# 5 * 8 =  40
# 5 * 9 =  45
# 5 * 10 =  50
# 5 * 11 =  55
# 5 * 12 =  60
#
# 6 * 0 =  0
# 6 * 1 =  6
# 6 * 2 =  12
# 6 * 3 =  18
# 6 * 4 =  24
# 6 * 5 =  30
# 6 * 6 =  36
# 6 * 7 =  42
# 6 * 8 =  48
# 6 * 9 =  54
# 6 * 10 =  60
# 6 * 11 =  66
# 6 * 12 =  72
#
# 7 * 0 =  0
# 7 * 1 =  7
# 7 * 2 =  14
# 7 * 3 =  21
# 7 * 4 =  28
# 7 * 5 =  35
# 7 * 6 =  42
# 7 * 7 =  49
# 7 * 8 =  56
# 7 * 9 =  63
# 7 * 10 =  70
# 7 * 11 =  77
# 7 * 12 =  84
#
# 8 * 0 =  0
# 8 * 1 =  8
# 8 * 2 =  16
# 8 * 3 =  24
# ...

# %%
x = int(input('value'))
i = 1
while i <= 12:
    print(x, '*', i, '=', x*i)
    i+=1
# Out:
# value30
# 30 * 1 = 30
# 30 * 2 = 60
# 30 * 3 = 90
# 30 * 4 = 120
# 30 * 5 = 150
# 30 * 6 = 180
# 30 * 7 = 210
# 30 * 8 = 240
# 30 * 9 = 270
# 30 * 10 = 300
# 30 * 11 = 330
# 30 * 12 = 360

# %%
def to_smash(no_candies, num_frd=3):
    return no_candies % num_frd

# %%
to_smash(10, 4)
# Out:
# 2

# %%
def can_run_for_president(age, is_natural_born_citizen):
    """Can someone of the given age and citizenship status run for president in the US?"""
    # The US Constitution says you must be a natural born citizen *and* at least 35 years old
    return is_natural_born_citizen and (age >= 35)

print(can_run_for_president(19, True))
print(can_run_for_president(55, False))
print(can_run_for_president(55, True))
# Out:
# False
# False
# True

# %%
def sign(a):
    if a in range(-9, 0):
        print(-1)
    elif a in range(1, 9):
        print(1)
    elif a == 0:
        print(0)
    else:
        print('not in range')

# %%
sign(-4)
# Out:
# -1

# %%
sign(4)
# Out:
# 1

# %%
sign(0)
# Out:
# 0

# %%
def to_smash(total_candies):
    
    if total_candies == 1:
        print('splitting ', total_candies, 'candy') 
    else:
        print("Splitting", total_candies, 'candies')
    return total_candies % 3

to_smash(91)
# Out:
# Splitting 91 candies
# 1

# %%
to_smash(1)
# Out:
# splitting  1 candy
# 1

# %%
def prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday):
    # Don't change this code. Our goal is just to find the bug, not fix it!
    return have_umbrella or rain_level < 5 and have_hood or not rain_level > 0 and is_workday

# Change the values of these inputs so they represent a case where prepared_for_weather
# returns the wrong answer.
have_umbrella = False
rain_level = 10.0
have_hood = True
is_workday = True

# Check what the function returns given the current values of the variables above
actual = prepared_for_weather(have_umbrella, rain_level, have_hood, is_workday)
print(actual)
# Out:
# False

# %%
def concise_is_negative(number):
    return True if number < 0 else False

# %%
concise_is_negative(-1)
# Out:
# True

# %%
concise_is_negative(4)
# Out:
# False

# %%
def onionless(ketchup, mustard, onion):
    """Return whether the customer doesn't want onions.
    """
    return not onion

# %%
onionless(True, True, False)
# Out:
# True

# %%
def wants_all_toppings(ketchup, mustard, onion):
    """Return whether the customer wants "the works" (all 3 toppings)
    """
    return ketchup and mustard and onion

# %%
wants_all_toppings(True, True, True)
# Out:
# True

# %%
def plain_hotdog(ketchup, mustard, onion):
    return not ketchup and not mustard and not onion

# %%
plain_hotdog(True, True, True)
# Out:
# False

# %%
def exactly_one(ketchup, mustard, onion):
    return ketchup ^ mustard and onion

# %%
exactly_one(False, True, True)
# Out:
# True

# %%
def exactly_one1(ketchup, mustard, onion):
    return (int(ketchup) + int(mustard) + int(onion)) == 1

# %%
exactly_one1(False, True, True)
# Out:
# False

# %%
def select_second(L):
    """Return the second element of the given list. If the list has no second
    element, return None.
    """
    return L[1]

# %%
select_second([1,3,5,7,9,2,4,6,8])
# Out:
# 3

# %%
def new(L):
    if len(L) <2:
        return None
    return L[1]

# %%
new([1,3,5,7,9,2,4,6,8])
# Out:
# 3

# %%
def purple_shell(racers):
    """Given a list of racers, set the first place racer (at the front of the list) to last
    place and vice versa.
    
    >>> r = ["Mario", "Bowser", "Luigi"]
    >>> purple_shell(r)
    >>> r
    ["Luigi", "Bowser", "Mario"]
    """
    a = racers[0]
    racers[0] = racers[-1]
    racers[-1] = a
    return racers

# %%
purple_shell(['dan', 'lei', 'ade'])
# Out:
# ['ade', 'lei', 'dan']

# %%
b = [1,2,3][1:]
len(b)
# Out:
# 2

# %%
party_attendees =

# %%
def fashionably_late(arrivals, name):
    """Given an ordered list of arrivals to the party and a name, return whether the guest with that
    name was fashionably late.
    """
    order = arrivals.index(name)
    return order >= len(arrivals) / 2 and order != len(arrivals) - 1

# %%
lengths = []
a = lengths.append(3)
b = lengths.append(2)
c = lengths.append(0)
d = lengths.append(1)

# %%
lengths
# Out:
# [3, 2, 0, 1]

# %%
length = []
a = 3
b = 2
c = 0
d = 1

# %%
length.append(a)
length.append(b)
length.append(c)
length.append(d)

# %%
length
# Out:
# [3, 2, 0, 1]

# %%
def has_lucky_number(nums):
    """Return whether the given list of numbers is lucky. A lucky list contains
    at least one number divisible by 7.
    """
    for num in nums:
        if num % 7 == 0:
            return True
        else:
            return False

# %%
has_lucky_number([5,3,67,1, 7])
# Out:
# False

# %%
def has_lucky_number(nums):
    return any([num % 7 == 0 for num in nums])

# %%
def elementwise_greater_than(L, thresh):
    """Return a list with the same length as L, where the value at index i is 
    True if L[i] is greater than thresh, and False otherwise.
    
    >>> elementwise_greater_than([1, 2, 3, 4], 2)
    [False, False, True, True]
    """
    for i in L:
        a = i > thresh
        print(bool(a), end=' ')

# %%
elementwise_greater_than([1,2,3,4,5,6,7], 3)
# Out:
# False False False True True True True

# %%
 b = []
    for i in L:
        b.append(i > thresh)
        return b

# %%
def menu_is_boring(meals):
    """Given a list of meals served over some period of time, return True if the
    same meal has ever been served two days in a row, and False otherwise.
    """
#     served = []
#     for meal in meals:
#         served.append(meal)
#         if meal in served >= 2:
#             return True
#         else:
#             return False
    for i in range(len(meals)-1):
            if meals[i] == meals[i+1]:
                return True
    return False

# %%
menu_is_boring(['a','b','c','d', 'b','e','f','g'])
# Out:
# False

# %%
def word_search(doc_list, keyword):
    """
    Takes a list of documents (each document is a string) and a keyword. 
    Returns list of the index values into the original list for all documents 
    containing the keyword.

    Example:
    doc_list = ["The Learn Python Challenge Casino.", "They bought a car", "Casinoville"]
    >>> word_search(doc_list, 'casino')
    >>> [0]
    """
    indices = [] 
    for i, doc in enumerate(doc_list):
        tokens = doc.split()
        normalized = [token.rstrip('.,').lower() for token in tokens]
        if keyword.lower() in normalized:
            indices.append(i)
    return indices

# %%
def multi_word_search(doc_list, keywords):
    """
    Takes list of documents (each document is a string) and a list of keywords.  
    Returns a dictionary where each key is a keyword, and the value is a list of indices
    (from doc_list) of the documents containing that keyword

    >>> doc_list = ["The Learn Python Challenge Casino.", "They bought a car and a casino", "Casinoville"]
    >>> keywords = ['casino', 'they']
    >>> multi_word_search(doc_list, keywords)
    {'casino': [0, 1], 'they': [1]}
    """
    keyword_to_indices = {}
    for keyword in keywords:
        keyword_to_indices[keyword] = word_search(doc_list, keyword)
    return keyword_to_indices

# %%
def blackjack_hand_greater_than(hand_1, hand_2):
    """
    Return True if hand_1 beats hand_2, and False otherwise.
    
    In order for hand_1 to beat hand_2 the following must be true:
    - The total of hand_1 must not exceed 21
    - The total of hand_1 must exceed the total of hand_2 OR hand_2's total must exceed 21
    
    Hands are represented as a list of cards. Each card is represented by a string.
    
    When adding up a hand's total, cards with numbers count for that many points. Face
    cards ('J', 'Q', and 'K') are worth 10 points. 'A' can count for 1 or 11.
    
    When determining a hand's total, you should try to count aces in the way that 
    maximizes the hand's total without going over 21. e.g. the total of ['A', 'A', '9'] is 21,
    the total of ['A', 'A', '9', '3'] is 14.
    
    Examples:
    >>> blackjack_hand_greater_than(['K'], ['3', '4'])
    True
    >>> blackjack_hand_greater_than(['K'], ['10'])
    False
    >>> blackjack_hand_greater_than(['K', 'K', '2'], ['3'])
    False
    """
     aces = 0
    for card in hand:
        if card in ['J', 'Q', 'K']:
            total += 10
        elif card == 'A':
            aces += 1
        else:
            # Convert number cards (e.g. '7') to ints
            total += int(card)
    # At this point, total is the sum of this hand's cards *not counting aces*.

    # Add aces, counting them as 1 for now. This is the smallest total we can make from this hand
    total += aces
    # "Upgrade" aces from 1 to 11 as long as it helps us get closer to 21
    # without busting
    while total + 10 <= 21 and aces > 0:
        # Upgrade an ace from 1 to 11
        total += 10
        aces -= 1
    return total

def blackjack_hand_greater_than(hand_1, hand_2):
    total_1 = hand_total(hand_1)
    total_2 = hand_total(hand_2)
    return total_1 <= 21 and (total_1 > total_2 or total_2 > 21)

# %%
def best_items(racers):
    winner_item_counts = {}
    for i in range(len(racers)):
        # The i'th racer dictionary
        racer = racers[i]
        # We're only interested in racers who finished in first
        if racer['finish'] == 1:
            for items in racer['items']:
                # Add one to the count for this item (adding it to the dict if necessary)
                if i not in winner_item_counts:
                    winner_item_counts[i] = 0
                winner_item_counts[i] += 1

        # Data quality issues :/ Print a warning about racers with no name set. We'll take care of it later.
        if racer['name'] is None:
            print("WARNING: Encountered racer with unknown name on iteration {}/{} (racer = {})".format(
                i+1, len(racers), racer['name'])
                 )
    return winner_item_counts

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('travel.csv')
df
# Out:
#      reason_for_travel         country  total_visitors
# 0             VACATION          U.S.A.          912314
# 1             VACATION          CANADA          300580
# 2    FRIENDS-RELATIVES          U.S.A.          186624
# 3                SPORT             VAC          136019
# 4             VACATION  UNITED KINGDOM          122638
# ..                 ...             ...             ...
# 864         MISSIONARY      OTHER ASIA               1
# 865      NOT SPECIFIED        PARAGUAY               1
# 866              OTHER       LUXEMBURG               1
# 867              OTHER        PARAGUAY               1
# 868              OTHER          TAIWAN               1
#
# [869 rows x 3 columns]

# %%
df.shape
# Out:
# (869, 3)

# %%
df.reason_for_travel.value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('reasons for travels')
plt.ylabel('frequency of travel')
# Out:
# Text(0, 0.5, 'frequency of travel')

# %%
#df.total_visitors.value_counts().sort_values(ascending=False).plot.pie()

# %%
df.isnull().mean()
# Out:
# reason_for_travel    0.0
# country              0.0
# total_visitors       0.0
# dtype: float64

# %%
df.describe()
# Out:
#        total_visitors
# count      869.000000
# mean      2733.000000
# std      34178.272604
# min          1.000000
# 25%          6.000000
# 50%         38.000000
# 75%        172.000000
# max     912314.000000

# %%
df2 = pd.read_csv('police.csv')

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   county_name         0 non-null      float64
#  3   driver_gender       86406 non-null  object
#  4   driver_age_raw      86414 non-null  float64
#  5   driver_age          86120 non-null  float64
#  6   driver_race         86408 non-null  object
#  7   violation_raw       86408 non-null  object
#  8   violation           86408 non-null  object
#  9   search_conducted    91741 non-null  bool
#  10  search_type         3196 non-null   object
#  11  stop_outcome        86408 non-null  object
#  12  is_arrested         86408 non-null  object
#  13  stop_duration       86408 non-null  object
#  14  drugs_related_stop  91741 non-null  bool
# ...

# %%
df2.isnull().sum()
# Out:
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5335
# driver_age_raw         5327
# driver_age             5621
# driver_race            5333
# violation_raw          5333
# violation              5333
# search_conducted          0
# search_type           88545
# stop_outcome           5333
# is_arrested            5333
# stop_duration          5333
# drugs_related_stop        0
# dtype: int64

# %%
df2
# Out:
#         stop_date stop_time  county_name driver_gender  driver_age_raw  \
# 0      2005-01-02     01:55          NaN             M          1985.0
# 1      2005-01-18     08:15          NaN             M          1965.0
# 2      2005-01-23     23:15          NaN             M          1972.0
# 3      2005-02-20     17:15          NaN             M          1986.0
# 4      2005-03-14     10:00          NaN             F          1984.0
# ...           ...       ...          ...           ...             ...
# 91736  2015-12-31     20:27          NaN             M          1986.0
# 91737  2015-12-31     20:35          NaN             F          1982.0
# 91738  2015-12-31     20:45          NaN             M          1992.0
# 91739  2015-12-31     21:42          NaN             M          1993.0
# 91740  2015-12-31     22:46          NaN             M          1959.0
#
#        driver_age driver_race                   violation_raw  \
# ...

# %%
mydf = df2
del mydf['county_name']
mydf
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
d2 = mydf.search_type.mode()
d2
# Out:
# 0    Incident to Arrest
# Name: search_type, dtype: object

# %%
mydf.dropna()
mydf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91741 entries, 0 to 91740
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   stop_date           91741 non-null  object
#  1   stop_time           91741 non-null  object
#  2   driver_gender       86406 non-null  object
#  3   driver_age_raw      86414 non-null  float64
#  4   driver_age          86120 non-null  float64
#  5   driver_race         86408 non-null  object
#  6   violation_raw       86408 non-null  object
#  7   violation           86408 non-null  object
#  8   search_conducted    91741 non-null  bool
#  9   search_type         3196 non-null   object
#  10  stop_outcome        86408 non-null  object
#  11  is_arrested         86408 non-null  object
#  12  stop_duration       86408 non-null  object
#  13  drugs_related_stop  91741 non-null  bool
# dtypes: bool(2), float64(2), object(10)
# memory usage: 8.6+ MB

# %%
mydf
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0      2005-01-02     01:55             M          1985.0        20.0
# 1      2005-01-18     08:15             M          1965.0        40.0
# 2      2005-01-23     23:15             M          1972.0        33.0
# 3      2005-02-20     17:15             M          1986.0        19.0
# 4      2005-03-14     10:00             F          1984.0        21.0
# ...           ...       ...           ...             ...         ...
# 91736  2015-12-31     20:27             M          1986.0        29.0
# 91737  2015-12-31     20:35             F          1982.0        33.0
# 91738  2015-12-31     20:45             M          1992.0        23.0
# 91739  2015-12-31     21:42             M          1993.0        22.0
# 91740  2015-12-31     22:46             M          1959.0        56.0
#
#       driver_race                   violation_raw         violation  \
# ...

# %%
median = mydf.driver_age.median()
print(median)
mean = mydf.driver_age.mean()
print(mean)
# Out:
# 31.0
# 34.011333023687875

# %%
new = df2.dropna()
new
# Out:
#         stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 24     2005-08-28     01:00             M          1979.0        26.0
# 40     2005-10-01     00:00             M          1988.0        17.0
# 41     2005-10-01     00:00             M          1988.0        17.0
# 80     2005-10-02     09:30             M          1975.0        30.0
# 106    2005-10-03     14:00             M          1978.0        27.0
# ...           ...       ...           ...             ...         ...
# 91494  2015-12-18     09:30             M          1966.0        49.0
# 91548  2015-12-21     01:39             M          1986.0        29.0
# 91672  2015-12-28     11:05             F          1996.0        19.0
# 91700  2015-12-30     08:51             F          1987.0        28.0
# 91708  2015-12-30     13:15             M          1992.0        23.0
#
#       driver_race                   violation_raw            violation  \
# ...

# %%
new.isnull().sum()
# Out:
# stop_date             0
# stop_time             0
# driver_gender         0
# driver_age_raw        0
# driver_age            0
# driver_race           0
# violation_raw         0
# violation             0
# search_conducted      0
# search_type           0
# stop_outcome          0
# is_arrested           0
# stop_duration         0
# drugs_related_stop    0
# dtype: int64

# %%
new.reset_index(inplace=True, drop=True)
new
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 0     2005-08-28     01:00             M          1979.0        26.0
# 1     2005-10-01     00:00             M          1988.0        17.0
# 2     2005-10-01     00:00             M          1988.0        17.0
# 3     2005-10-02     09:30             M          1975.0        30.0
# 4     2005-10-03     14:00             M          1978.0        27.0
# ...          ...       ...           ...             ...         ...
# 3188  2015-12-18     09:30             M          1966.0        49.0
# 3189  2015-12-21     01:39             M          1986.0        29.0
# 3190  2015-12-28     11:05             F          1996.0        19.0
# 3191  2015-12-30     08:51             F          1987.0        28.0
# 3192  2015-12-30     13:15             M          1992.0        23.0
#
#      driver_race                   violation_raw            violation  \
# ...

# %%
df3 = new[new['driver_gender'] == 'F']
df3
# Out:
#        stop_date stop_time driver_gender  driver_age_raw  driver_age  \
# 9     2005-10-07     12:45             F          1981.0        24.0
# 28    2005-10-20     01:52             F          1986.0        19.0
# 43    2005-11-01     02:45             F          1986.0        19.0
# 45    2005-11-02     01:45             F          1987.0        18.0
# 46    2005-11-02     01:45             F          1987.0        18.0
# ...          ...       ...           ...             ...         ...
# 3157  2015-10-16     13:51             F          1989.0        26.0
# 3168  2015-11-03     13:13             F          1991.0        24.0
# 3173  2015-11-16     00:22             F          1986.0        29.0
# 3190  2015-12-28     11:05             F          1996.0        19.0
# 3191  2015-12-30     08:51             F          1987.0        28.0
#
#      driver_race            violation_raw            violation  \
# 9          Black                 Speeding             Speeding
# ...
